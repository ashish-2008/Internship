# %%
# Customer Retention Data Analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')


df=pd.read_csv(r'C:\ProgramData\customer_retention_dataset.csv')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
# We have 269 rows and 71 columns in dataset

# %%
# Exploratory Data Analysis

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# EXPLORATORY DATA ANALYSIS THROUGH DATA VISUALIZATION

#Categorical Variables
df_cat = df.select_dtypes(include=['object'])

# %%
cat_col = list(df_cat.columns.values)

# %%
# EXPLORATORY DATA ANALYSIS THROUGH DATA VISUALIZATION

for column in cat_col:
    
    
    df[column].value_counts().plot.bar(title = column)
    plt.tight_layout()
    plt.show()

# %%
# Important Observations from above bar plot of different features:
# 1) "Female" customers are more online shoppers compared to "Male
# 2) Customers between age group "31-40 ,21-30 and 41-50" are maximum,which means maximum customers are of young age group
# 3) Maximum customers belong to the NCR region i.e customers from Delhi,Greater Noida ,Noida are the maximum followed by
# Bangalore ,Kamal,Solan,Ghaziabad,Gurgaon etc
# 4) Maximum online shoppers have been shopping since more than 4 years followed by 2-3 years ,3-4 years
# 5) Customers with less than 10 times online purchase in last 1 year are maximum followed by 31-40 times , >41 times so on
# 6) Maximum customers shop using mobile internet which shows mobile base customer is maximum followed by wifi customers
# 7) 'Smartphone' users are the maximum followed by Laptop , Desktop
# 8) Customers with mobile screen size others , 5.5 inches are most followed by 4.7 , 5 inches
# 9) Maximum customers use 'Google Chrome' as browser for online shopping followed by safari,opera
# 10) Most Customers favorite online store for first time is "Search engine" followed  by Content Marketing ,Display Ads
# 11) Best medium to online retail store is "searcg engine" for most customers followed by application,direct url
# 12) Maximum average time spent by customer in exploring the e-retail store before making a purchase decision is 
# > 15 min followed by 6-10 min , 11-15 min 
# 13) Most favorite payment option of most customers is credit/debit cards followed by COD,E-Wallets
# 14) Most customers abandon their shopping cart "sometimes" followed by 'Never','frequently'
# 15) Maximum reason for abandoning cart is "better alternative offers" followed by "promo code not applicable" ,change in price
# 16) Most customers "strongly agree" that content on the website must be easy to read and understand followed by "agree"
# 17) Most customers "strongly agree" for product comparision followed by "agree" ,"indifferent"
# 18) Most customers "strongly agree" for the complete info for listed seller and product is important for purchase decision
# 19) Majority of customers "strongly agree " for  loading speed should be fast for website , for easy navigation and user 
# friendly interface of the website
# 20) Majority of customers "strongly agree" with the fact that payment method should be convenient
# 21) Most of the customers "stronly agree" with that privacy of the customer is important , empathy is important and Trust is 
# extremely important 
# 22) Most customers "strongly agree" with the fact that online shopping provides monetary benefits,discounts etc and that 
# gaining access to loyalty programs is a benefit of online shopping
# 23) Majority of customers "stronly agree" with the fact that online shopping gives them adventure ,enjoyment
# and online shopping is convenient and flexible
# 24) Maximum customers "stronly agree" with that return and replacement policy of e-retailer is important for purchase decision
# 25) Most customers "stronly agree" that "Trust" is important for user satisfaction
# 26) Most customers want wide variety in variety of listed product
# 27) Majority of the customers are of the opinion that they get value for the money they spent with online shopping
# 28) Majority of customers feel that amazon ,flipkart have best visual appealing web page layout
# 29) Majority of customers feel that amazon ,flipkart have wild variety of product offers
# 30) Majority of customers feel that complete and relevan information of products is listed on amazon,flipkart
# 31) Majority of customers feel that amazon,paytm have fast loading websites
# 32) Most customers feel that amazon , flipkart,paytm website are most quick to complete the purchase
# 33) Most customers feel that amazon , flipkart,myntra ,snapdeal have availability of several payment options
# 34) Majority of customers agree that amazon ,flipkart have fastest speedy order delivery
# 35) Majority of customers agree that amazon ,flipkart,myntra maintain privacy of customers information
# 36) MOst customers feel that approx all websites maintain security of customer financial information
# 37) MOst customers feel that "Flipkart" has fastest login in time during sales ,promotions period
